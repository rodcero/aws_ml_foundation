# %%
import time
import pandas as pd
import numpy as np

# %%
with open('books_published_last_two_years.txt') as f:
    recent_books = f.read().split('\n')
    
with open('all_coding_books.txt') as f:
    coding_books = f.read().split('\n')

print(recent_books, coding_books)
# Out:
# '8436642', '3503044', '5057831', '4630494', '3917052', '8701849', '7099724', '6983126', '5279537', '7015558', '6064414', '9500886', '2994882', '7057752', '4817235', '1419685', '6007124', '3636084', '2778395', '6890466', '6116299', '9459812', '5925941', '5116749', '8514894', '2228874', '8831832', '9740220', '4650983', '6513354', '9499926', '6908419', '5179267', '1968256', '1243498', '8528220', '9487307', '8932130', '6792796', '4195341', '9381269', '7593596', '3853264', '3004635', '7249873', '5031085', '8022337', '3573408', '8233347', '4708630', '3238576', '6998134', '3564038', '7454211', '7694254', '2825990', '7591972', '7052296', '5500091', '5051835', '8611404', '8349970', '3902203', '1664080', '7460217', '3065571', '7664575', '1438262', '7393110', '3898330', '5147633', '3066175', '7460752', '4933900', '4699251', '2600540', '7547667', '4427233', '9614033', '4089597', '3083702', '4864131', '6173826', '6910983', '8961744', '7619805', '7572111', '4127590', '3860456', '8688305', '3015426
# ...
